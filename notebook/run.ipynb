# %%
# %load_ext autoreload
# %autoreload 2

# %%
from exonamd.run import *

# %%
df = create_db(from_scratch=False)
# Out:
# 2024-08-19 15:42:02.219 | INFO     | exonamd.catalog:download_nasa_confirmed_planets:16 - Downloading NASA Exoplanet Archive confirmed planets
# 2024-08-19 15:42:02.244 | DEBUG    | exonamd.catalog:download_nasa_confirmed_planets:27 - Defining the SQL query to retrieve the required data
# 2024-08-19 15:42:02.245 | DEBUG    | exonamd.catalog:download_nasa_confirmed_planets:64 - Making the request to the API
# 2024-08-19 15:42:03.610 | ERROR    | exonamd.catalog:download_nasa_confirmed_planets:73 - Error: 404 in fetching data
# 2024-08-19 15:42:03.612 | ERROR    | __main__:<module>:1 - An error has been caught in function '<module>', process 'MainProcess' (1528341), thread 'MainThread' (140369506957120):
# Traceback (most recent call last):
#
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
# ...

# %%
df = interp_db(df)
# Out:
# 2024-08-19 14:23:09.225 | INFO     | exonamd.run:interp_db:123 - Thinning down the data with nanmedian
# 2024-08-19 14:23:09.253 | INFO     | exonamd.run:interp_db:128 - Data thinned down
# 2024-08-19 14:23:09.254 | INFO     | exonamd.run:interp_db:130 - Checking for duplicates
# 2024-08-19 14:23:09.258 | INFO     | exonamd.run:interp_db:138 - No duplicates found
# 2024-08-19 14:23:09.259 | INFO     | exonamd.run:interp_db:140 - Instantiating the flags
# 2024-08-19 14:23:09.261 | INFO     | exonamd.run:interp_db:142 - Flags instantiated
# 2024-08-19 14:23:09.262 | INFO     | exonamd.run:interp_db:144 - Interpolating missing eccentricity values
# Pandas Apply:   0%|          | 0/2418 [00:00<?, ?it/s]
# 2024-08-19 14:23:10.173 | INFO     | exonamd.run:interp_db:153 - Values interpolated
# 2024-08-19 14:23:10.175 | INFO     | exonamd.run:interp_db:155 - Interpolating missing planetary mass values
# Pandas Apply:   0%|          | 0/2418 [00:00<?, ?it/s]
# ...

# %%
df = calc_namd(df)
# Out:
# 2024-08-19 14:25:34.176 | DEBUG    | exonamd.run:calc_namd:242 - Dropping columns that are no longer needed
# 2024-08-19 14:25:34.179 | DEBUG    | exonamd.run:calc_namd:244 - Columns dropped
# 2024-08-19 14:25:34.181 | INFO     | exonamd.run:calc_namd:247 - Computing the relative NAMD
# 2024-08-19 14:25:35.960 | INFO     | exonamd.run:calc_namd:255 - Relative NAMD computed
# 2024-08-19 14:25:35.961 | INFO     | exonamd.run:calc_namd:257 - Computing the absolute NAMD
# 2024-08-19 14:25:37.831 | INFO     | exonamd.run:calc_namd:265 - Absolute NAMD computed
# 2024-08-19 14:25:37.833 | INFO     | exonamd.run:calc_namd:294 - Defining the core sample
# 2024-08-19 14:25:38.021 | INFO     | exonamd.run:calc_namd:297 - Core sample defined
# 2024-08-19 14:25:38.022 | INFO     | exonamd.run:calc_namd:316 - Computing the Monte Carlo relative NAMD
# 2024-08-19 14:25:45.237 | INFO     | exonamd.run:calc_namd:326 - Relative NAMD computed
# ...

# %%
plot_sample_namd(df=df, title="Core systems")
# Out:
# 2024-08-19 14:25:52.635 | INFO     | exonamd.run:plot_sample_namd:364 - Plotting the NAMD vs. multiplicity
# 2024-08-19 14:25:53.168 | INFO     | exonamd.run:plot_sample_namd:376 - Plot done
