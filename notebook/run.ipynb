# %%
# %load_ext autoreload
# %autoreload 2

# %%
from exonamd.run import *

# %%
df = create_db(from_scratch=True)
# Out:
# 2024-08-19 17:27:49.017 | INFO     | exonamd.catalog:download_nasa_confirmed_planets:17 - Downloading NASA Exoplanet Archive confirmed planets
# 2024-08-19 17:27:49.045 | DEBUG    | exonamd.catalog:download_nasa_confirmed_planets:28 - Defining the SQL query to retrieve the required data
# 2024-08-19 17:27:49.047 | DEBUG    | exonamd.catalog:download_nasa_confirmed_planets:65 - Making the request to the API
# 2024-08-19 17:27:51.326 | INFO     | exonamd.catalog:download_nasa_confirmed_planets:81 - Data fetched
# 2024-08-19 17:27:51.330 | INFO     | exonamd.utils:fetch_aliases:311 - Fetching aliases for host stars
# 2024-08-19 17:27:55.675 | INFO     | exonamd.utils:fetch_nea_aliases:159 - Fetched 3/3 entries on try 1
# 2024-08-19 17:27:55.742 | INFO     | exonamd.run:create_db:62 - Updating host and planet names
# ...
# Pandas Apply:   0%|          | 0/6 [00:00<?, ?it/s]
# 2024-08-19 17:27:55.772 | DEBUG    | exonamd.utils:update_planet:433 - Updating planet TOI-1338 b to TOI-1338 A b
# ...

# %%
df = interp_db(df=df)
# Out:
# 2024-08-19 17:28:10.505 | INFO     | exonamd.run:interp_db:123 - Thinning down the data with nanmedian
# 2024-08-19 17:28:10.535 | INFO     | exonamd.run:interp_db:128 - Data thinned down
# 2024-08-19 17:28:10.536 | INFO     | exonamd.run:interp_db:130 - Checking for duplicates
# 2024-08-19 17:28:10.540 | INFO     | exonamd.run:interp_db:138 - No duplicates found
# 2024-08-19 17:28:10.541 | INFO     | exonamd.run:interp_db:140 - Instantiating the flags
# 2024-08-19 17:28:10.543 | INFO     | exonamd.run:interp_db:142 - Flags instantiated
# 2024-08-19 17:28:10.543 | INFO     | exonamd.run:interp_db:144 - Interpolating missing eccentricity values
# Pandas Apply:   0%|          | 0/2418 [00:00<?, ?it/s]
# 2024-08-19 17:28:11.577 | INFO     | exonamd.run:interp_db:153 - Values interpolated
# 2024-08-19 17:28:11.579 | INFO     | exonamd.run:interp_db:155 - Interpolating missing planetary mass values
# Pandas Apply:   0%|          | 0/2418 [00:00<?, ?it/s]
# ...

# %%
df = calc_namd(df)

# %%
plot_sample_namd(df=df, title="Core systems")
