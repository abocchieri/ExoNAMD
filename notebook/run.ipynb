# %%
# %load_ext autoreload
# %autoreload 2

# %%
from exonamd.run import *
# Out:
# /home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pytools/persistent_dict.py:59: UserWarning: Unable to import recommended hash 'siphash24.siphash13', falling back to 'hashlib.sha256'. Run 'python3 -m pip install siphash24' to install the recommended hash.
#   warn("Unable to import recommended hash 'siphash24.siphash13', "

# %%
df = create_db(from_scratch=False)
# Out:
# 2024-08-19 23:28:15.731 | INFO     | exonamd.catalog:download_nasa_confirmed_planets:17 - Downloading NASA Exoplanet Archive confirmed planets
# 2024-08-19 23:28:15.762 | DEBUG    | exonamd.catalog:download_nasa_confirmed_planets:28 - Defining the SQL query to retrieve the required data
# 2024-08-19 23:28:15.763 | DEBUG    | exonamd.catalog:download_nasa_confirmed_planets:65 - Making the request to the API
# 2024-08-19 23:28:18.077 | INFO     | exonamd.catalog:download_nasa_confirmed_planets:81 - Data fetched
# 2024-08-19 23:28:18.080 | INFO     | exonamd.utils:fetch_aliases:311 - Fetching aliases for host stars and their planets
# 2024-08-19 23:28:22.458 | INFO     | exonamd.utils:fetch_nea_aliases:159 - Fetched 3/3 entries on try 1
# 2024-08-19 23:28:22.526 | INFO     | exonamd.utils:fetch_aliases:403 - Aliases fetched.
# 2024-08-19 23:28:22.528 | INFO     | exonamd.utils:fetch_aliases:406 - Saving aliases to pickle
# ...

# %%
df = interp_db(df)
# Out:
# 2024-08-19 23:28:23.213 | INFO     | exonamd.run:interp_db:127 - Thinning down the data with nanmedian
# /home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/swifter/swifter.py:87: UserWarning: This pandas object has duplicate indices, and swifter may not be able to improve performance. Consider resetting the indices with `df.reset_index(drop=True)`.
#   warnings.warn(
# 2024-08-19 23:28:23.255 | INFO     | exonamd.run:interp_db:132 - Data thinned down
# 2024-08-19 23:28:23.257 | INFO     | exonamd.run:interp_db:134 - Checking for duplicates
# 2024-08-19 23:28:23.266 | INFO     | exonamd.run:interp_db:142 - No duplicates found
# 2024-08-19 23:28:23.267 | INFO     | exonamd.run:interp_db:144 - Instantiating the flags
# 2024-08-19 23:28:23.268 | INFO     | exonamd.run:interp_db:146 - Flags instantiated
# 2024-08-19 23:28:23.269 | INFO     | exonamd.run:interp_db:148 - Interpolating missing eccentricity values
# Pandas Apply:   0%|          | 0/2418 [00:00<?, ?it/s]
# ...

# %%
df = calc_namd(df, core=True)
# Out:
# 2024-08-19 23:31:22.188 | DEBUG    | exonamd.run:calc_namd:246 - Dropping columns that are no longer needed
# 2024-08-19 23:31:22.193 | DEBUG    | exonamd.run:calc_namd:248 - Columns dropped
# 2024-08-19 23:31:22.196 | INFO     | exonamd.run:calc_namd:251 - Computing the relative NAMD
# 2024-08-19 23:31:25.000 | INFO     | exonamd.run:calc_namd:259 - Relative NAMD computed
# 2024-08-19 23:31:25.002 | INFO     | exonamd.run:calc_namd:261 - Computing the absolute NAMD
# 2024-08-19 23:31:27.872 | INFO     | exonamd.run:calc_namd:269 - Absolute NAMD computed
# 2024-08-19 23:31:27.874 | INFO     | exonamd.run:calc_namd:298 - Defining the core sample
# 2024-08-19 23:31:28.229 | INFO     | exonamd.run:calc_namd:301 - Core sample defined
# 2024-08-19 23:31:28.232 | INFO     | exonamd.run:calc_namd:320 - Computing the Monte Carlo relative NAMD
# 2024-08-19 23:31:36.712 | INFO     | exonamd.run:calc_namd:330 - Relative NAMD computed
# ...

# %%
plot_sample_namd(df, title="Core systems")
# Out:
# 2024-08-19 23:31:45.812 | INFO     | exonamd.run:plot_sample_namd:368 - Plotting the NAMD vs. multiplicity
# 2024-08-19 23:31:46.472 | INFO     | exonamd.run:plot_sample_namd:379 - Plot done
