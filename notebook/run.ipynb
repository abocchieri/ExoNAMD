# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd

from exonamd.run import *
from exonamd.utils import ROOT

# %%
# df_db = create_db(from_scratch=False)

# %%
df = pd.read_csv(os.path.join(ROOT, "data", "exo.csv"))
df_SS = pd.read_csv(os.path.join(ROOT, "data", "custom_db_20241017.csv"))

# %%
df
# Out:
#           hostname        pl_name  default_flag   rowupdate  sy_pnum  \
# 0       Kepler-407   Kepler-407 b             1  2025-08-07        2
# 1       HD 93963 A   HD 93963 A b             0  2025-08-07        2
# 2        Kepler-10    Kepler-10 b             0  2025-08-07        3
# 3        Kepler-20    Kepler-20 d             0  2017-03-28        6
# 4       Kepler-188   Kepler-188 c             0  2019-04-16        2
# ...            ...            ...           ...         ...      ...
# 18511    HD 153557    HD 153557 d             1  2023-06-12        3
# 18512     HIP 8541     HIP 8541 c             1  2023-06-14        2
# 18513  Kepler-1085  Kepler-1085 b             1  2016-05-06        2
# 18514     HIP 5158     HIP 5158 c             1  2015-09-08        2
# 18515   Kepler-444   Kepler-444 d             1  2015-01-29        5
#
#        pl_orbsmax  pl_orbsmaxerr1  pl_orbsmaxerr2  pl_rade  pl_radeerr1  ...  \
# 0        0.014924             NaN             NaN     1.19        0.050  ...
# 1        0.020643             NaN             NaN     1.49        0.040  ...
# 2        0.016726             NaN             NaN     1.47        0.030  ...
# 3        0.345300          0.0041         -0.0046     2.75        0.170  ...
# 4        0.065023             NaN             NaN      NaN          NaN  ...
# ...           ...             ...             ...      ...          ...  ...
# 18511   21.449000          1.4870         -1.7460      NaN          NaN  ...
# 18512    0.923000          0.0190         -0.0220      NaN          NaN  ...
# 18513    0.736936             NaN             NaN     7.22        1.770  ...
# 18514    7.700000          1.8800         -1.8800      NaN          NaN  ...
# 18515    0.060000          0.0011         -0.0011     0.53        0.022  ...
#
#        pl_bmasseerr2  pl_orbeccen  pl_orbeccenerr1  pl_orbeccenerr2  \
# 0          -0.500000          NaN              NaN              NaN
# 1          -1.660000          NaN              NaN              NaN
# 2          -0.330000          NaN              NaN              NaN
# 3                NaN        0.600              NaN              NaN
# 4                NaN          NaN              NaN              NaN
# ...              ...          ...              ...              ...
# 18511   -1111.128111        0.152            0.060           -0.047
# 18512     -50.852545        0.169            0.142           -0.102
# 18513            NaN          NaN              NaN              NaN
# 18514   -3353.106500        0.140            0.100           -0.100
# 18515            NaN        0.180            0.160           -0.120
#
#        pl_orbincl  pl_orbinclerr1  pl_orbinclerr2  pl_trueobliq  \
# 0             NaN             NaN             NaN           NaN
# 1             NaN             NaN             NaN           NaN
# 2             NaN             NaN             NaN           NaN
# 3          89.570           0.043          -0.048           NaN
# 4             NaN             NaN             NaN           NaN
# ...           ...             ...             ...           ...
# 18511      14.324           0.964          -0.935           NaN
# 18512         NaN             NaN             NaN           NaN
# 18513         NaN             NaN             NaN           NaN
# 18514         NaN             NaN             NaN           NaN
# 18515      88.160           0.810          -0.550           NaN
#
#        pl_trueobliqerr1  pl_trueobliqerr2
# 0                   NaN               NaN
# 1                   NaN               NaN
# 2                   NaN               NaN
# 3                   NaN               NaN
# 4                   NaN               NaN
# ...                 ...               ...
# 18511               NaN               NaN
# 18512               NaN               NaN
# 18513               NaN               NaN
# 18514               NaN               NaN
# 18515               NaN               NaN
#
# [18516 rows x 23 columns]

# %%
# df_db = pd.concat([df, df_SS], ignore_index=True)

# %%
df_interp_db = interp_db(df=df)
# df_interp_db = interp_db(df=df_db)
# Out:
# 2025-08-08 16:57:30.091 | INFO     | exonamd.run:interp_db:168 - Thinning down the data with nanmedian
# 2025-08-08 16:57:30.127 | INFO     | exonamd.run:interp_db:182 - Data thinned down
# 2025-08-08 16:57:30.129 | INFO     | exonamd.run:interp_db:184 - Checking for duplicates
# 2025-08-08 16:57:30.133 | INFO     | exonamd.run:interp_db:192 - No duplicates found
# 2025-08-08 16:57:30.134 | INFO     | exonamd.run:interp_db:194 - Instantiating the flags
# 2025-08-08 16:57:30.135 | INFO     | exonamd.run:interp_db:196 - Flags instantiated
# 2025-08-08 16:57:30.136 | INFO     | exonamd.run:interp_db:198 - Interpolating missing eccentricity values
# NaT values in rowupdate: 0
# Empty DataFrame
# Columns: [hostname, pl_name]
# Index: []
# 0       2025-08-07
# 1       2025-08-07
# 2       2025-08-07
# 3       2017-03-28
# 4       2019-04-16
#            ...
# 18511   2023-06-12
# 18512   2023-06-14
# 18513   2016-05-06
# 18514   2015-09-08
# 18515   2015-01-29
# Name: rowupdate, Length: 18516, dtype: datetime64[ns]
# hostname
# 14 Her                     15440
# 24 Sex                      5363
# 2MASS J19383260+4603591     8395
# 47 UMa                     12475
# 55 Cnc                     16643
#                            ...
# iot Dra                    15272
# nu Oph                      9101
# rho CrB                     9088
# tau Cet                     7138
# ups And                    17660
# Name: rowupdate, Length: 1005, dtype: int64
# Pandas Apply:   0%|          | 0/1005 [00:00<?, ?it/s]
# 2025-08-08 16:57:30.615 | INFO     | exonamd.run:interp_db:207 - Values interpolated
# 2025-08-08 16:57:30.617 | INFO     | exonamd.run:interp_db:209 - Interpolating missing planetary mass values
# Pandas Apply:   0%|          | 0/1005 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/swifter/swifter.py:421, in DataFrameAccessor.apply(self, func, axis, raw, result_type, args, **kwds)
#     420     sample_df = sample.apply(func, axis=axis, raw=raw, result_type=result_type, args=args, **kwds)
# --> 421     self._validate_apply(
#     422         np.array_equal(sample_df, tmp_df) & (hasattr(tmp_df, "shape")) & (sample_df.shape == tmp_df.shape),
#     423         error_message=("Vectorized function sample does not match pandas apply sample."),
#     424     )
#     425 return func(self._obj, *args, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/swifter/base.py:53, in _SwifterBaseObject._validate_apply(expr, error_message)
#      52 if not expr:
# ---> 53     raise ValueError(error_message)
#
# ValueError: Vectorized function sample does not match pandas apply sample.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_interp_db = interp_db(df=df)
#       2 # df_interp_db = interp_db(df=df_db)
#
# File /export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/run.py:217, in interp_db(df)
#     207 logger.info("Values interpolated")
#     209 logger.info("Interpolating missing planetary mass values")
#     210 df[
#     211     [
#     212         "pl_bmasse",
#     213         "pl_bmasseerr1",
#     214         "pl_bmasseerr2",
#     215         "flag",
#     216     ]
# --> 217 ] = df.swifter.apply(interp_mass, axis=1)
#     218 logger.info("Values interpolated")
#     220 logger.debug("Dropping columns that are no longer needed")
#
# File ~/.local/lib/python3.10/site-packages/swifter/swifter.py:437, in DataFrameAccessor.apply(self, func, axis, raw, result_type, args, **kwds)
#     435     return self._parallel_apply(func, axis, raw, result_type, *args, **kwds)
#     436 else:  # use pandas
# --> 437     return self._pandas_apply(self._obj, func, axis, raw, result_type, *args, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/swifter/swifter.py:350, in DataFrameAccessor._pandas_apply(self, df, func, axis, raw, result_type, *args, **kwds)
#     347 else:
#     348     apply_func = df.apply
# --> 350 return apply_func(func, axis=axis, raw=raw, result_type=result_type, args=args, **kwds)
#
# File /ariel/data/andrea.bocchieri/.conda/envs/exo_namd/lib/python3.10/site-packages/tqdm/std.py:917, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     914 # Apply the provided function (in **kwargs)
#     915 # on the df using our wrapper (which provides bar updating)
#     916 try:
# --> 917     return getattr(df, df_function)(wrapper, **kwargs)
#     918 finally:
#     919     t.close()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File /ariel/data/andrea.bocchieri/.conda/envs/exo_namd/lib/python3.10/site-packages/tqdm/std.py:912, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     906 def wrapper(*args, **kwargs):
#     907     # update tbar correctly
#     908     # it seems `pandas apply` calls `func` twice
#     909     # on the first column/row to decide whether it can
#     910     # take a fast or slow code path; so stop when t.total==t.n
#     911     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 912     return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/loguru/_logger.py:1277, in Logger.catch.<locals>.Catcher.__call__.<locals>.catch_wrapper(*args, **kwargs)
#    1275 def catch_wrapper(*args, **kwargs):
#    1276     with catcher:
# -> 1277         return function(*args, **kwargs)
#    1278     return default
#
# File /export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/interp.py:95, in interp_mass(row, min_radius, max_radius)
#      85 flag = get_value(row["flag"])
#      87 if (
#      88     np.isnan(mass)
#      89     and not np.isnan(radius)
#    (...)
#      93     and not np.isnan(radiuserr2)
#      94 ):
# ---> 95     mds = rmr.predict_mass(radius=(radius, 0.5 * (radiuserr1 - radiuserr2)))
#      96     q16, q50, q84 = np.percentile(mds.samples, [16, 50, 84])
#      97     mass = q50
#
# File ~/.local/lib/python3.10/site-packages/spright/rmrelation.py:168, in RMRelation.predict_mass(self, radius, nsamples)
#     166 v = 4 / 3 * pi * (rs * u.R_earth).to(u.cm) ** 3
#     167 m_g = v * s * (u.g / u.cm ** 3)
# --> 168 return Distribution(m_g.to(u.M_earth).value, 'mass', self._identify_modes(rs.mean(), 'mass'))
#
# File ~/.local/lib/python3.10/site-packages/spright/distribution.py:58, in Distribution.__init__(self, samples, quantity, modes, fit)
#      55 self._m2: Optional[float] = None
#      57 if fit:
# ---> 58     self._fit_distribution(*modes)
#
# File ~/.local/lib/python3.10/site-packages/spright/distribution.py:102, in Distribution._fit_distribution(self, m1, m2)
#      99         return inf
#     100     return -log(dmodel(self.samples, pv)).sum() / self.size
# --> 102 self._minimization_result = res = minimize(minfun, array([0.5, m1, 0.5, 1.5, m2, 0.5, 1.5]),
#     103                                            method='powell')
#     104 self.model, self.model_pars, self._m1, self._m2 = dmodel, res.x, res.x[1], res.x[4]
#     105 return dmodel, res.x, res.x[1], res.x[4]
#
# File /ariel/data/andrea.bocchieri/.conda/envs/exo_namd/lib/python3.10/site-packages/scipy/optimize/_minimize.py:690, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     687     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     688                                **options)
#     689 elif meth == 'powell':
# --> 690     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     691 elif meth == 'cg':
#     692     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#
# File /ariel/data/andrea.bocchieri/.conda/envs/exo_namd/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3181, in _minimize_powell(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3179 direc1 = direc[i]
#    3180 fx2 = fval
# -> 3181 fval, x, direc1 = _linesearch_powell(func, x, direc1,
#    3182                                      tol=xtol * 100,
#    3183                                      lower_bound=lower_bound,
#    3184                                      upper_bound=upper_bound,
#    3185                                      fval=fval)
#    3186 if (fx2 - fval) > delta:
#    3187     delta = fx2 - fval
#
# File /ariel/data/andrea.bocchieri/.conda/envs/exo_namd/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2910, in _linesearch_powell(func, p, xi, tol, lower_bound, upper_bound, fval)
#    2907     return ((fval, p, xi) if fval is not None else (func(p), p, xi))
#    2908 elif lower_bound is None and upper_bound is None:
#    2909     # non-bounded minimization
# -> 2910     alpha_min, fret, _, _ = brent(myfunc, full_output=1, tol=tol)
#    2911     xi = alpha_min * xi
#    2912     return squeeze(fret), p + xi, xi
#
# File /ariel/data/andrea.bocchieri/.conda/envs/exo_namd/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2461, in brent(func, args, brack, tol, full_output, maxiter)
#    2390 """
#    2391 Given a function of one variable and a possible bracket, return
#    2392 the local minimum of the function isolated to a fractional precision
#    (...)
#    2457
#    2458 """
#    2459 options = {'xtol': tol,
#    2460            'maxiter': maxiter}
# -> 2461 res = _minimize_scalar_brent(func, brack, args, **options)
#    2462 if full_output:
#    2463     return res['x'], res['fun'], res['nit'], res['nfev']
#
# File /ariel/data/andrea.bocchieri/.conda/envs/exo_namd/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2498, in _minimize_scalar_brent(func, brack, args, xtol, maxiter, disp, **unknown_options)
#    2495 brent = Brent(func=func, args=args, tol=tol,
#    2496               full_output=True, maxiter=maxiter, disp=disp)
#    2497 brent.set_bracket(brack)
# -> 2498 brent.optimize()
#    2499 x, fval, nit, nfev = brent.get_result(full_output=True)
#    2501 success = nit < maxiter and not (np.isnan(x) or np.isnan(fval))
#
# File /ariel/data/andrea.bocchieri/.conda/envs/exo_namd/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2275, in Brent.optimize(self)
#    2271 #################################
#    2272 #BEGIN CORE ALGORITHM
#    2273 #################################
#    2274 x = w = v = xb
# -> 2275 fw = fv = fx = func(*((x,) + self.args))
#    2276 if (xa < xc):
#    2277     a = xa
#
# File /ariel/data/andrea.bocchieri/.conda/envs/exo_namd/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2903, in _linesearch_powell.<locals>.myfunc(alpha)
#    2902 def myfunc(alpha):
# -> 2903     return func(p + alpha*xi)
#
# File /ariel/data/andrea.bocchieri/.conda/envs/exo_namd/lib/python3.10/site-packages/scipy/optimize/_optimize.py:496, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     494 ncalls[0] += 1
#     495 # A copy of x is sent to the user function (gh13740)
# --> 496 fx = function(np.copy(x), *(wrapper_args + args))
#     497 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     498 # backwards-compatibility, also allow np.array([1.3]),
#     499 # np.array([[1.3]]) etc.
#     500 if not np.isscalar(fx):
#
# File ~/.local/lib/python3.10/site-packages/spright/distribution.py:100, in Distribution._fit_distribution.<locals>.minfun(pv)
#      98 if any(pv < 0.0) or pv[0] > 1 or any(pv[[3, 6]] > 7.0) or (pv[1] > pv[4]):
#      99     return inf
# --> 100 return -log(dmodel(self.samples, pv)).sum() / self.size
#
# File ~/.local/lib/python3.10/site-packages/spright/distribution.py:95, in Distribution._fit_distribution.<locals>.dmodel(x, pv)
#      94 def dmodel(x, pv):
# ---> 95     return (1 - pv[0]) * spdf(x, *pv[1:4]) + pv[0] * spdf(x, *pv[4:])
#
# File /ariel/data/andrea.bocchieri/.conda/envs/exo_namd/lib/python3.10/site-packages/numba/core/serialize.py:30, in _numba_unpickle(address, bytedata, hashed)
#      26 # Keep unpickled object via `numba_unpickle` alive.
#      27 _unpickled_memo = {}
# ---> 30 def _numba_unpickle(address, bytedata, hashed):
#      31     """Used by `numba_unpickle` from _helperlib.c
#      32
#      33     Parameters
#    (...)
#      42         unpickled object
#      43     """
#      44     key = (address, hashed)
#
# KeyboardInterrupt:

# %%
df_interp_db_ = df_interp_db.copy()

# %%
core_flags = ["0", "05+", "05-", "05+-"]
condition = lambda x: all(x["flag"].isin(core_flags)) and x["hostname"].isin(["SS", "SSE"])
# Out:
#       hostname pl_name rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
# 18419       SS     Ssb       NaN        8       0.387             0.0
# 18420       SS     Ssc       NaN        8       0.723             0.0
# 18421       SS     Ssd       NaN        8       1.000             0.0
# 18422       SS     Sse       NaN        8       1.524             0.0
# 18423       SS     Ssf       NaN        8       5.204             0.0
# 18424       SS     Ssg       NaN        8       9.573             0.0
# 18425       SS     Ssh       NaN        8      19.165             0.0
# 18426       SS     Ssi       NaN        8      30.178             0.0
# 18427      SSE    Sseb       NaN        8       0.387             0.0
# 18428      SSE    Ssec       NaN        8       0.723             0.0
# 18429      SSE    Ssed       NaN        8       1.000             0.0
# 18430      SSE    Ssee       NaN        8       1.524             0.0
# 18431      SSE    Ssef       NaN        8       5.204             0.0
# 18432      SSE    Sseg       NaN        8       9.573             0.0
# 18433      SSE    Sseh       NaN        8      19.165             0.0
# 18434      SSE    Ssei       NaN        8      30.178             0.0
#
#        pl_orbsmaxerr2   pl_bmasse  pl_bmasseerr1  pl_bmasseerr2  ...  \
# 18419             0.0    0.055276            0.0            0.0  ...
# 18420             0.0    0.815745            0.0            0.0  ...
# 18421             0.0    1.000000            0.0            0.0  ...
# 18422             0.0    0.107538            0.0            0.0  ...
# 18423             0.0  317.922948            0.0            0.0  ...
# 18424             0.0   95.142379            0.0            0.0  ...
# 18425             0.0   14.539363            0.0            0.0  ...
# 18426             0.0   17.085427            0.0            0.0  ...
# 18427             0.0    0.055276            0.0            0.0  ...
# 18428             0.0    0.815745            0.0            0.0  ...
# 18429             0.0    1.000000            0.0            0.0  ...
# 18430             0.0    0.107538            0.0            0.0  ...
# 18431             0.0  317.922948            0.0            0.0  ...
# 18432             0.0   95.142379            0.0            0.0  ...
# 18433             0.0   14.539363            0.0            0.0  ...
# 18434             0.0   17.085427            0.0            0.0  ...
#
#        pl_trueobliqerr2  st_rad  st_mass  pl_orbper  pl_ratdor  pl_ratror  \
# 18419               0.0     NaN      NaN        NaN        NaN        NaN
# 18420               0.0     NaN      NaN        NaN        NaN        NaN
# 18421               0.0     NaN      NaN        NaN        NaN        NaN
# 18422               0.0     NaN      NaN        NaN        NaN        NaN
# 18423               0.0     NaN      NaN        NaN        NaN        NaN
# 18424               0.0     NaN      NaN        NaN        NaN        NaN
# 18425               0.0     NaN      NaN        NaN        NaN        NaN
# 18426               0.0     NaN      NaN        NaN        NaN        NaN
# 18427               0.0     NaN      NaN        NaN        NaN        NaN
# 18428               0.0     NaN      NaN        NaN        NaN        NaN
# 18429               0.0     NaN      NaN        NaN        NaN        NaN
# 18430               0.0     NaN      NaN        NaN        NaN        NaN
# 18431               0.0     NaN      NaN        NaN        NaN        NaN
# 18432               0.0     NaN      NaN        NaN        NaN        NaN
# 18433               0.0     NaN      NaN        NaN        NaN        NaN
# 18434               0.0     NaN      NaN        NaN        NaN        NaN
#
#                     flag  pl_relincl  pl_relinclerr1  pl_relinclerr2
# 18419  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18420  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18421  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18422  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18423  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18424  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18425  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18426  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18427  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18428  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18429  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18430  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18431  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18432  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18433  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
# 18434  01+1-2+2-4+4-5+5-         NaN             NaN             NaN
#
# [16 rows x 28 columns]

# %%
df_namd = calc_namd(df=df_interp_db_, core=True, filt=condition)
# Out:
# 2025-07-09 21:25:18.576 | DEBUG    | exonamd.run:calc_namd:305 - Dropping columns that are no longer needed
# 2025-07-09 21:25:18.581 | DEBUG    | exonamd.run:calc_namd:307 - Columns dropped
# 2025-07-09 21:25:18.583 | INFO     | exonamd.run:calc_namd:310 - Computing the relative NAMD
# 2025-07-09 21:25:21.645 | INFO     | exonamd.run:calc_namd:318 - Relative NAMD computed
# 2025-07-09 21:25:21.647 | INFO     | exonamd.run:calc_namd:320 - Computing the absolute NAMD
# 2025-07-09 21:25:24.825 | INFO     | exonamd.run:calc_namd:328 - Absolute NAMD computed
# 2025-07-09 21:25:24.827 | INFO     | exonamd.run:calc_namd:357 - Defining the core sample
# 2025-07-09 21:25:25.260 | INFO     | exonamd.run:calc_namd:360 - Core sample defined
# 2025-07-09 21:25:25.262 | INFO     | exonamd.run:calc_namd:379 - Computing the Monte Carlo relative NAMD
# 2025-07-09 21:25:25.459 | ERROR    | pandas.core.groupby.groupby:f:1809 - An error has been caught in function 'f', process 'MainProcess' (1524647), thread 'MainThread' (140130099988288):
# Traceback (most recent call last):
#
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f7294718500, file "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/...
#            └ <function _run_code at 0x7f72948f91b0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7f7294718500, file "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/...
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/k...
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7f7291e00ca0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f729488c3a0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7f7291e01870>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f7291e32d40>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f729488c3a0>
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7f7293758940>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f7291e32d40>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7f729375a440>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7f72936f97e0>
#     └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#           │    └ <function Kernel.process_one at 0x7f7291fbf880>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x7f7291e33340>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#           │         └ ([<zmq.sugar.frame.Frame object at 0x7f70fd669380>, <zmq.sugar.frame.Frame object at 0x7f7107393ab0>, <zmq.sugar.frame.Frame ...
#           └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f7291e33340>>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#           └ <coroutine object IPythonKernel.execute_request at 0x7f70eb56cf90>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#                                   │       │      └ {'header': {'date': datetime.datetime(2025, 7, 9, 19, 25, 18, 11000, tzinfo=tzutc()), 'msg_id': '77ebc18d-b009-477a-a818-95bf...
#                                   │       └ [b'cbced136-4bf3-4e3e-b988-0a37c884c775']
#                                   └ <zmq.eventloop.zmqstream.ZMQStream object at 0x7f7291e32aa0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x7f70eb56cba0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7f7291ff6320>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': 'vscode-notebook-cell://ssh-remote%2Bmelodie/home/ariel/andrea.bocchieri/...
#                              └ ('df_namd = calc_namd(df=df_interp_db_, core=True)',)
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7f7292b9e3b0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#              │      └ <coroutine object InteractiveShell.run_cell_async at 0x7f70eb56d620>
#              └ <function _pseudo_sync_runner at 0x7f7292b7dcf0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7f70eb56d620>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '/tmp/ipykernel_1524647/1513511993.py'
#                        │    │             │        └ [<ast.Assign object at 0x7f72886106d0>]
#                        │    │             └ <ast.Module object at 0x7f70fc310820>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7f7292b9e680>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 7f70ebacd720, execution_count=126 error_before_exec=None error_in_exec=None info=<ExecutionInfo ob...
#              │    │        └ <code object <module> at 0x7f70ec6bd160, file "/tmp/ipykernel_1524647/1513511993.py", line 1>
#              │    └ <function InteractiveShell.run_code at 0x7f7292b9e710>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#          │         │    └ <property object at 0x7f7292b7bbf0>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#          └ <code object <module> at 0x7f70ec6bd160, file "/tmp/ipykernel_1524647/1513511993.py", line 1>
#
#   File "/tmp/ipykernel_1524647/1513511993.py", line 1, in <module>
#     df_namd = calc_namd(df=df_interp_db_, core=True)
#               │            └          hostname       pl_name   rowupdate  sy_pnum  pl_orbsmax  \
#               │              5      Kepler-257  Kepler-257 b  2014-05-14        3    0...
#               └ <function calc_namd at 0x7f71073cd480>
#
#   File "/export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/run.py", line 380, in calc_namd
#     df = groupby_apply_merge(
#          └ <function groupby_apply_merge at 0x7f710e9ba290>
#
#   File "/export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/utils.py", line 443, in groupby_apply_merge
#     retval = df.groupby(groupby).apply(func, *args, **kwargs)
#              │  │       │              │      │       └ {'kind': 'rel', 'Npt': 250000, 'threshold': 1000}
#              │  │       │              │      └ ()
#              │  │       │              └ <function solve_namd_mc at 0x7f710e9bbbe0>
#              │  │       └ 'hostname'
#              │  └ <function DataFrame.groupby at 0x7f71bc1b8c10>
#              └       hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#                538     14 Her  14 Her b  2023-06-12        2   ...
#
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py", line 1824, in apply
#     result = self._python_apply_general(f, self._selected_obj)
#              │    │                     │  │    └ <pandas._libs.properties.CachedProperty object at 0x7f71bbd4d100>
#              │    │                     │  └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#              │    │                     └ <function solve_namd_mc at 0x7f70eb901510>
#              │    └ <function GroupBy._python_apply_general at 0x7f71bbd4a200>
#              └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py", line 1885, in _python_apply_general
#     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#                       │    │        │               │  │     │    └ 0
#                       │    │        │               │  │     └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#                       │    │        │               │  └       hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#                       │    │        │               │    538     14 Her  14 Her b  2023-06-12        2   ...
#                       │    │        │               └ <function solve_namd_mc at 0x7f70eb901510>
#                       │    │        └ <function BaseGrouper.apply_groupwise at 0x7f71bc1ea560>
#                       │    └ <pandas.core.groupby.ops.BaseGrouper object at 0x7f70ee0a7c70>
#                       └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py", line 919, in apply_groupwise
#     res = f(group)
#           │ └     hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#           │   540   24 Sex  24 Sex b  2014-05-14        2       ...
#           └ <function solve_namd_mc at 0x7f70eb901510>
# > File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py", line 1809, in f
#     return func(g, *args, **kwargs)
#            │    │   │       └ {'kind': 'rel', 'Npt': 250000, 'threshold': 1000}
#            │    │   └ ()
#            │    └     hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#            │      540   24 Sex  24 Sex b  2014-05-14        2       ...
#            └ <function solve_namd_mc at 0x7f710e9bbbe0>
#
#   File "/export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/solve.py", line 378, in solve_namd_mc
#     namd = namd.compressed()
#            └ nan
#
# AttributeError: 'numpy.float64' object has no attribute 'compressed'. Did you mean: 'compress'?
# 2025-07-09 21:25:26.120 | ERROR    | pandas.core.groupby.groupby:f:1809 - An error has been caught in function 'f', process 'MainProcess' (1524647), thread 'MainThread' (140130099988288):
# Traceback (most recent call last):
#
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f7294718500, file "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/...
#            └ <function _run_code at 0x7f72948f91b0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7f7294718500, file "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/...
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/k...
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7f7291e00ca0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f729488c3a0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7f7291e01870>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f7291e32d40>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f729488c3a0>
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7f7293758940>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f7291e32d40>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7f729375a440>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7f72936f97e0>
#     └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#           │    └ <function Kernel.process_one at 0x7f7291fbf880>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x7f7291e33340>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#           │         └ ([<zmq.sugar.frame.Frame object at 0x7f70fd669380>, <zmq.sugar.frame.Frame object at 0x7f7107393ab0>, <zmq.sugar.frame.Frame ...
#           └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f7291e33340>>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#           └ <coroutine object IPythonKernel.execute_request at 0x7f70eb56cf90>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#                                   │       │      └ {'header': {'date': datetime.datetime(2025, 7, 9, 19, 25, 18, 11000, tzinfo=tzutc()), 'msg_id': '77ebc18d-b009-477a-a818-95bf...
#                                   │       └ [b'cbced136-4bf3-4e3e-b988-0a37c884c775']
#                                   └ <zmq.eventloop.zmqstream.ZMQStream object at 0x7f7291e32aa0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x7f70eb56cba0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7f7291ff6320>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': 'vscode-notebook-cell://ssh-remote%2Bmelodie/home/ariel/andrea.bocchieri/...
#                              └ ('df_namd = calc_namd(df=df_interp_db_, core=True)',)
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7f7292b9e3b0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#              │      └ <coroutine object InteractiveShell.run_cell_async at 0x7f70eb56d620>
#              └ <function _pseudo_sync_runner at 0x7f7292b7dcf0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7f70eb56d620>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '/tmp/ipykernel_1524647/1513511993.py'
#                        │    │             │        └ [<ast.Assign object at 0x7f72886106d0>]
#                        │    │             └ <ast.Module object at 0x7f70fc310820>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7f7292b9e680>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 7f70ebacd720, execution_count=126 error_before_exec=None error_in_exec=None info=<ExecutionInfo ob...
#              │    │        └ <code object <module> at 0x7f70ec6bd160, file "/tmp/ipykernel_1524647/1513511993.py", line 1>
#              │    └ <function InteractiveShell.run_code at 0x7f7292b9e710>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#          │         │    └ <property object at 0x7f7292b7bbf0>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#          └ <code object <module> at 0x7f70ec6bd160, file "/tmp/ipykernel_1524647/1513511993.py", line 1>
#
#   File "/tmp/ipykernel_1524647/1513511993.py", line 1, in <module>
#     df_namd = calc_namd(df=df_interp_db_, core=True)
#               │            └          hostname       pl_name   rowupdate  sy_pnum  pl_orbsmax  \
#               │              5      Kepler-257  Kepler-257 b  2014-05-14        3    0...
#               └ <function calc_namd at 0x7f71073cd480>
#
#   File "/export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/run.py", line 380, in calc_namd
#     df = groupby_apply_merge(
#          └ <function groupby_apply_merge at 0x7f710e9ba290>
#
#   File "/export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/utils.py", line 443, in groupby_apply_merge
#     retval = df.groupby(groupby).apply(func, *args, **kwargs)
#              │  │       │              │      │       └ {'kind': 'rel', 'Npt': 250000, 'threshold': 1000}
#              │  │       │              │      └ ()
#              │  │       │              └ <function solve_namd_mc at 0x7f710e9bbbe0>
#              │  │       └ 'hostname'
#              │  └ <function DataFrame.groupby at 0x7f71bc1b8c10>
#              └       hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#                538     14 Her  14 Her b  2023-06-12        2   ...
#
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py", line 1824, in apply
#     result = self._python_apply_general(f, self._selected_obj)
#              │    │                     │  │    └ <pandas._libs.properties.CachedProperty object at 0x7f71bbd4d100>
#              │    │                     │  └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#              │    │                     └ <function solve_namd_mc at 0x7f70eb901510>
#              │    └ <function GroupBy._python_apply_general at 0x7f71bbd4a200>
#              └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py", line 1885, in _python_apply_general
#     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#                       │    │        │               │  │     │    └ 0
#                       │    │        │               │  │     └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#                       │    │        │               │  └       hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#                       │    │        │               │    538     14 Her  14 Her b  2023-06-12        2   ...
#                       │    │        │               └ <function solve_namd_mc at 0x7f70eb901510>
#                       │    │        └ <function BaseGrouper.apply_groupwise at 0x7f71bc1ea560>
#                       │    └ <pandas.core.groupby.ops.BaseGrouper object at 0x7f70ee0a7c70>
#                       └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py", line 919, in apply_groupwise
#     res = f(group)
#           │ └     hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#           │   545   47 UMa  47 UMa b  2014-05-14        3       ...
#           └ <function solve_namd_mc at 0x7f70eb901510>
# > File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py", line 1809, in f
#     return func(g, *args, **kwargs)
#            │    │   │       └ {'kind': 'rel', 'Npt': 250000, 'threshold': 1000}
#            │    │   └ ()
#            │    └     hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#            │      545   47 UMa  47 UMa b  2014-05-14        3       ...
#            └ <function solve_namd_mc at 0x7f710e9bbbe0>
#
#   File "/export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/solve.py", line 378, in solve_namd_mc
#     namd = namd.compressed()
#            └ nan
#
# AttributeError: 'numpy.float64' object has no attribute 'compressed'. Did you mean: 'compress'?
# 2025-07-09 21:25:27.121 | ERROR    | pandas.core.groupby.groupby:f:1809 - An error has been caught in function 'f', process 'MainProcess' (1524647), thread 'MainThread' (140130099988288):
# Traceback (most recent call last):
#
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f7294718500, file "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/...
#            └ <function _run_code at 0x7f72948f91b0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7f7294718500, file "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/...
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/k...
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7f7291e00ca0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f729488c3a0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7f7291e01870>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f7291e32d40>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f729488c3a0>
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7f7293758940>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f7291e32d40>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7f729375a440>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7f72936f97e0>
#     └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#           │    └ <function Kernel.process_one at 0x7f7291fbf880>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x7f7291e33340>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#           │         └ ([<zmq.sugar.frame.Frame object at 0x7f70fd669380>, <zmq.sugar.frame.Frame object at 0x7f7107393ab0>, <zmq.sugar.frame.Frame ...
#           └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f7291e33340>>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#           └ <coroutine object IPythonKernel.execute_request at 0x7f70eb56cf90>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#                                   │       │      └ {'header': {'date': datetime.datetime(2025, 7, 9, 19, 25, 18, 11000, tzinfo=tzutc()), 'msg_id': '77ebc18d-b009-477a-a818-95bf...
#                                   │       └ [b'cbced136-4bf3-4e3e-b988-0a37c884c775']
#                                   └ <zmq.eventloop.zmqstream.ZMQStream object at 0x7f7291e32aa0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x7f70eb56cba0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7f7291ff6320>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': 'vscode-notebook-cell://ssh-remote%2Bmelodie/home/ariel/andrea.bocchieri/...
#                              └ ('df_namd = calc_namd(df=df_interp_db_, core=True)',)
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7f7292b9e3b0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#              │      └ <coroutine object InteractiveShell.run_cell_async at 0x7f70eb56d620>
#              └ <function _pseudo_sync_runner at 0x7f7292b7dcf0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7f70eb56d620>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '/tmp/ipykernel_1524647/1513511993.py'
#                        │    │             │        └ [<ast.Assign object at 0x7f72886106d0>]
#                        │    │             └ <ast.Module object at 0x7f70fc310820>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7f7292b9e680>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 7f70ebacd720, execution_count=126 error_before_exec=None error_in_exec=None info=<ExecutionInfo ob...
#              │    │        └ <code object <module> at 0x7f70ec6bd160, file "/tmp/ipykernel_1524647/1513511993.py", line 1>
#              │    └ <function InteractiveShell.run_code at 0x7f7292b9e710>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#          │         │    └ <property object at 0x7f7292b7bbf0>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#          └ <code object <module> at 0x7f70ec6bd160, file "/tmp/ipykernel_1524647/1513511993.py", line 1>
#
#   File "/tmp/ipykernel_1524647/1513511993.py", line 1, in <module>
#     df_namd = calc_namd(df=df_interp_db_, core=True)
#               │            └          hostname       pl_name   rowupdate  sy_pnum  pl_orbsmax  \
#               │              5      Kepler-257  Kepler-257 b  2014-05-14        3    0...
#               └ <function calc_namd at 0x7f71073cd480>
#
#   File "/export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/run.py", line 380, in calc_namd
#     df = groupby_apply_merge(
#          └ <function groupby_apply_merge at 0x7f710e9ba290>
#
#   File "/export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/utils.py", line 443, in groupby_apply_merge
#     retval = df.groupby(groupby).apply(func, *args, **kwargs)
#              │  │       │              │      │       └ {'kind': 'rel', 'Npt': 250000, 'threshold': 1000}
#              │  │       │              │      └ ()
#              │  │       │              └ <function solve_namd_mc at 0x7f710e9bbbe0>
#              │  │       └ 'hostname'
#              │  └ <function DataFrame.groupby at 0x7f71bc1b8c10>
#              └       hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#                538     14 Her  14 Her b  2023-06-12        2   ...
#
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py", line 1824, in apply
#     result = self._python_apply_general(f, self._selected_obj)
#              │    │                     │  │    └ <pandas._libs.properties.CachedProperty object at 0x7f71bbd4d100>
#              │    │                     │  └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#              │    │                     └ <function solve_namd_mc at 0x7f70eb901510>
#              │    └ <function GroupBy._python_apply_general at 0x7f71bbd4a200>
#              └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py", line 1885, in _python_apply_general
#     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#                       │    │        │               │  │     │    └ 0
#                       │    │        │               │  │     └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#                       │    │        │               │  └       hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#                       │    │        │               │    538     14 Her  14 Her b  2023-06-12        2   ...
#                       │    │        │               └ <function solve_namd_mc at 0x7f70eb901510>
#                       │    │        └ <function BaseGrouper.apply_groupwise at 0x7f71bc1ea560>
#                       │    └ <pandas.core.groupby.ops.BaseGrouper object at 0x7f70ee0a7c70>
#                       └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py", line 919, in apply_groupwise
#     res = f(group)
#           │ └     hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#           │   619   61 Vir  61 Vir b  2014-05-14        3     0....
#           └ <function solve_namd_mc at 0x7f70eb901510>
# > File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py", line 1809, in f
#     return func(g, *args, **kwargs)
#            │    │   │       └ {'kind': 'rel', 'Npt': 250000, 'threshold': 1000}
#            │    │   └ ()
#            │    └     hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#            │      619   61 Vir  61 Vir b  2014-05-14        3     0....
#            └ <function solve_namd_mc at 0x7f710e9bbbe0>
#
#   File "/export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/solve.py", line 378, in solve_namd_mc
#     namd = namd.compressed()
#            └ nan
#
# AttributeError: 'numpy.float64' object has no attribute 'compressed'. Did you mean: 'compress'?
# 2025-07-09 21:25:27.752 | ERROR    | pandas.core.groupby.groupby:f:1809 - An error has been caught in function 'f', process 'MainProcess' (1524647), thread 'MainThread' (140130099988288):
# Traceback (most recent call last):
#
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f7294718500, file "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/...
#            └ <function _run_code at 0x7f72948f91b0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7f7294718500, file "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/...
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/k...
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7f7291e00ca0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f729488c3a0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7f7291e01870>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f7291e32d40>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f729488c3a0>
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7f7293758940>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f7291e32d40>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7f729375a440>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7f72936f97e0>
#     └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle Task.task_wakeup(<Future finis...850>, ...],))>)>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#           │    └ <function Kernel.process_one at 0x7f7291fbf880>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x7f7291e33340>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#           │         └ ([<zmq.sugar.frame.Frame object at 0x7f70fd669380>, <zmq.sugar.frame.Frame object at 0x7f7107393ab0>, <zmq.sugar.frame.Frame ...
#           └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f7291e33340>>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#           └ <coroutine object IPythonKernel.execute_request at 0x7f70eb56cf90>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#                                   │       │      └ {'header': {'date': datetime.datetime(2025, 7, 9, 19, 25, 18, 11000, tzinfo=tzutc()), 'msg_id': '77ebc18d-b009-477a-a818-95bf...
#                                   │       └ [b'cbced136-4bf3-4e3e-b988-0a37c884c775']
#                                   └ <zmq.eventloop.zmqstream.ZMQStream object at 0x7f7291e32aa0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x7f70eb56cba0>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7f7291ff6320>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': 'vscode-notebook-cell://ssh-remote%2Bmelodie/home/ariel/andrea.bocchieri/...
#                              └ ('df_namd = calc_namd(df=df_interp_db_, core=True)',)
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7f7292b9e3b0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#   File "/ariel/data/andrea.bocchieri/.conda/envs/exonamd/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#              │      └ <coroutine object InteractiveShell.run_cell_async at 0x7f70eb56d620>
#              └ <function _pseudo_sync_runner at 0x7f7292b7dcf0>
# ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#          │         │    └ <property object at 0x7f7292b7bbf0>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f72901a7f70>
#          └ <code object <module> at 0x7f70ec6bd160, file "/tmp/ipykernel_1524647/1513511993.py", line 1>
#
#   File "/tmp/ipykernel_1524647/1513511993.py", line 1, in <module>
#     df_namd = calc_namd(df=df_interp_db_, core=True)
#               │            └          hostname       pl_name   rowupdate  sy_pnum  pl_orbsmax  \
#               │              5      Kepler-257  Kepler-257 b  2014-05-14        3    0...
#               └ <function calc_namd at 0x7f71073cd480>
#
#   File "/export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/run.py", line 380, in calc_namd
#     df = groupby_apply_merge(
#          └ <function groupby_apply_merge at 0x7f710e9ba290>
#
#   File "/export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/utils.py", line 443, in groupby_apply_merge
#     retval = df.groupby(groupby).apply(func, *args, **kwargs)
#              │  │       │              │      │       └ {'kind': 'rel', 'Npt': 250000, 'threshold': 1000}
#              │  │       │              │      └ ()
#              │  │       │              └ <function solve_namd_mc at 0x7f710e9bbbe0>
#              │  │       └ 'hostname'
#              │  └ <function DataFrame.groupby at 0x7f71bc1b8c10>
#              └       hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#                538     14 Her  14 Her b  2023-06-12        2   ...
#
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py", line 1824, in apply
#     result = self._python_apply_general(f, self._selected_obj)
#              │    │                     │  │    └ <pandas._libs.properties.CachedProperty object at 0x7f71bbd4d100>
#              │    │                     │  └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#              │    │                     └ <function solve_namd_mc at 0x7f70eb901510>
#              │    └ <function GroupBy._python_apply_general at 0x7f71bbd4a200>
#              └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py", line 1885, in _python_apply_general
#     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#                       │    │        │               │  │     │    └ 0
#                       │    │        │               │  │     └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#                       │    │        │               │  └       hostname   pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#                       │    │        │               │    538     14 Her  14 Her b  2023-06-12        2   ...
#                       │    │        │               └ <function solve_namd_mc at 0x7f70eb901510>
#                       │    │        └ <function BaseGrouper.apply_groupwise at 0x7f71bc1ea560>
#                       │    └ <pandas.core.groupby.ops.BaseGrouper object at 0x7f70ee0a7c70>
#                       └ <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f70efeae4d0>
#   File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py", line 919, in apply_groupwise
#     res = f(group)
#           │ └      hostname    pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#           │   2257  GJ 3138  GJ 3138 b  2017-03-29        3   ...
#           └ <function solve_namd_mc at 0x7f70eb901510>
# > File "/home/ariel/andrea.bocchieri/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py", line 1809, in f
#     return func(g, *args, **kwargs)
#            │    │   │       └ {'kind': 'rel', 'Npt': 250000, 'threshold': 1000}
#            │    │   └ ()
#            │    └      hostname    pl_name   rowupdate  sy_pnum  pl_orbsmax  pl_orbsmaxerr1  \
#            │      2257  GJ 3138  GJ 3138 b  2017-03-29        3   ...
#            └ <function solve_namd_mc at 0x7f710e9bbbe0>
#
#   File "/export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/solve.py", line 378, in solve_namd_mc
#     namd = namd.compressed()
#            └ nan
#
# AttributeError: 'numpy.float64' object has no attribute 'compressed'. Did you mean: 'compress'?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/loguru/_logger.py:1277, in Logger.catch.<locals>.Catcher.__call__.<locals>.catch_wrapper(*args, **kwargs)
#    1276 with catcher:
# -> 1277     return function(*args, **kwargs)
#    1278 return default
#
# File /export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/solve.py:378, in solve_namd_mc(host, kind, Npt, threshold, full)
#     377 namd = compute_namd(amdk, mass, sqrt_sma)
# --> 378 namd = namd.compressed()
#     380 if len(namd) < threshold:
#
# AttributeError: 'numpy.float64' object has no attribute 'compressed'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 df_namd = calc_namd(df=df_interp_db_, core=True)
#
# File /export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/run.py:380, in calc_namd(df, plot, core)
#     377 threshold = 1000
#     379 logger.info("Computing the Monte Carlo relative NAMD")
# --> 380 df = groupby_apply_merge(
#     381     df,
#     382     "hostname",
#     383     solve_namd_mc,
#     384     kind="rel",
#     385     Npt=Npt,
#     386     threshold=threshold,
#     387     allow_overwrite=True,
#     388 )
#     389 logger.info("Relative NAMD computed")
#     391 logger.info("Computing the Monte Carlo absolute NAMD")
#
# File ~/.local/lib/python3.10/site-packages/loguru/_logger.py:1277, in Logger.catch.<locals>.Catcher.__call__.<locals>.catch_wrapper(*args, **kwargs)
#    1275 def catch_wrapper(*args, **kwargs):
#    1276     with catcher:
# -> 1277         return function(*args, **kwargs)
#    1278     return default
#
# File /export/NAS/ariel/data/andrea.bocchieri/ExoNAMD/exonamd/utils.py:443, in groupby_apply_merge(df, groupby, func, allow_overwrite, *args, **kwargs)
#     441 @logger.catch
#     442 def groupby_apply_merge(df, groupby, func, *args, allow_overwrite=False, **kwargs):
# --> 443     retval = df.groupby(groupby).apply(func, *args, **kwargs)
#     445     if allow_overwrite:
#     446         # Identify columns that would cause a conflict during the merge
#     447         overlapping_columns = retval.columns.intersection(df.columns)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1824, in GroupBy.apply(self, func, include_groups, *args, **kwargs)
#    1822 with option_context("mode.chained_assignment", None):
#    1823     try:
# -> 1824         result = self._python_apply_general(f, self._selected_obj)
#    1825         if (
#    1826             not isinstance(self.obj, Series)
#    1827             and self._selection is None
#    1828             and self._selected_obj.shape != self._obj_with_exclusions.shape
#    1829         ):
#    1830             warnings.warn(
#    1831                 message=_apply_groupings_depr.format(
#    1832                     type(self).__name__, "apply"
#    (...)
#    1835                 stacklevel=find_stack_level(),
#    1836             )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1885, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1850 @final
#    1851 def _python_apply_general(
#    1852     self,
#    (...)
#    1857     is_agg: bool = False,
#    1858 ) -> NDFrameT:
#    1859     """
#    1860     Apply function f in python space
#    1861
#    (...)
#    1883         data after applying f
#    1884     """
# -> 1885     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1886     if not_indexed_same is None:
#    1887         not_indexed_same = mutated
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:919, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     917 # group might be modified
#     918 group_axes = group.axes
# --> 919 res = f(group)
#     920 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     921     mutated = True
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1809, in GroupBy.apply.<locals>.f(g)
#    1807 @wraps(func)
#    1808 def f(g):
# -> 1809     return func(g, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/loguru/_logger.py:1276, in Logger.catch.<locals>.Catcher.__call__.<locals>.catch_wrapper(*args, **kwargs)
#    1275 def catch_wrapper(*args, **kwargs):
# -> 1276     with catcher:
#    1277         return function(*args, **kwargs)
#    1278     return default
#
# File ~/.local/lib/python3.10/site-packages/loguru/_logger.py:1243, in Logger.catch.<locals>.Catcher.__exit__(self, type_, value, traceback_)
#    1240     depth += 1
#    1242 catch_options = [(type_, value, traceback_), depth, True] + options
# -> 1243 logger._log(level, from_decorator, catch_options, message, (), {})
#    1245 if onerror is not None:
#    1246     onerror(value)
#
# File ~/.local/lib/python3.10/site-packages/loguru/_logger.py:2032, in Logger._log(self, level, from_decorator, options, message, args, kwargs)
#    2029     patcher(log_record)
#    2031 for handler in core.handlers.values():
# -> 2032     handler.emit(log_record, level_id, from_decorator, raw, colored_message)
#
# File ~/.local/lib/python3.10/site-packages/loguru/_handler.py:147, in Handler.emit(self, record, level_id, from_decorator, is_raw, colored_message)
#     145     formatter = self._exception_formatter
#     146     lines = formatter.format_exception(type_, value, tb, from_decorator=from_decorator)
# --> 147     formatter_record["exception"] = "".join(lines)
#     149 if colored_message is not None and colored_message.stripped != record["message"]:
#     150     colored_message = None
#
# File ~/.local/lib/python3.10/site-packages/loguru/_better_exceptions.py:528, in ExceptionFormatter.format_exception(self, type_, value, tb, from_decorator)
#     527 def format_exception(self, type_, value, tb, *, from_decorator=False):
# --> 528     yield from self._format_exception(value, tb, is_first=True, from_decorator=from_decorator)
#
# File ~/.local/lib/python3.10/site-packages/loguru/_better_exceptions.py:447, in ExceptionFormatter._format_exception(self, value, tb, seen, is_first, from_decorator, group_nesting)
#     444 except AttributeError:
#     445     traceback_limit = None
# --> 447 frames, final_source = self._extract_frames(
#     448     exc_traceback, is_first, limit=traceback_limit, from_decorator=from_decorator
#     449 )
#     450 exception_only = traceback.format_exception_only(exc_type, exc_value)
#     452 # Determining the correct index for the "Exception: message" part in the formatted exception
#     453 # is challenging. This is because it might be preceded by multiple lines specific to
#     454 # "SyntaxError" or followed by various notes. However, we can make an educated guess based
#     455 # on the indentation; the preliminary context for "SyntaxError" is always indented, while
#     456 # the Exception itself is not. This allows us to identify the correct index for the
#     457 # exception message.
#
# File ~/.local/lib/python3.10/site-packages/loguru/_better_exceptions.py:249, in ExceptionFormatter._extract_frames(self, tb, is_first, limit, from_decorator)
#     247 if self._diagnose:
#     248     relevant_values = self._get_relevant_values(source, frame)
# --> 249     values = self._format_relevant_values(list(relevant_values), colorize)
#     250     lines += list(values)
#     251 source = "\n    ".join(lines)
#
# File ~/.local/lib/python3.10/site-packages/loguru/_better_exceptions.py:289, in ExceptionFormatter._get_relevant_values(self, source, frame)
#     287             is_valid_value = False
#     288         else:
# --> 289             yield (col, self._format_value(value))
#     290 elif type_ == tokenize.OP and string == ".":
#     291     is_attribute = True
#
# File ~/.local/lib/python3.10/site-packages/loguru/_better_exceptions.py:333, in ExceptionFormatter._format_value(self, v)
#     331 def _format_value(self, v):
#     332     try:
# --> 333         v = repr(v)
#     334     except Exception:
#     335         v = "<unprintable %s object>" % type(v).__name__
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1214, in DataFrame.__repr__(self)
#    1211     return buf.getvalue()
#    1213 repr_params = fmt.get_dataframe_repr_params()
# -> 1214 return self.to_string(**repr_params)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1376, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1373 from pandas import option_context
#    1375 with option_context("display.max_colwidth", max_colwidth):
# -> 1376     formatter = fmt.DataFrameFormatter(
#    1377         self,
#    1378         columns=columns,
#    1379         col_space=col_space,
#    1380         na_rep=na_rep,
#    1381         formatters=formatters,
#    1382         float_format=float_format,
#    1383         sparsify=sparsify,
#    1384         justify=justify,
#    1385         index_names=index_names,
#    1386         header=header,
#    1387         index=index,
#    1388         min_rows=min_rows,
#    1389         max_rows=max_rows,
#    1390         max_cols=max_cols,
#    1391         show_dimensions=show_dimensions,
#    1392         decimal=decimal,
#    1393     )
#    1394     return fmt.DataFrameRenderer(formatter).to_string(
#    1395         buf=buf,
#    1396         encoding=encoding,
#    1397         line_width=line_width,
#    1398     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:469, in DataFrameFormatter.__init__(self, frame, columns, col_space, header, index, na_rep, formatters, justify, float_format, sparsify, index_names, max_rows, min_rows, max_cols, show_dimensions, decimal, bold_rows, escape)
#     466 self.max_rows_fitted = self._calc_max_rows_fitted()
#     468 self.tr_frame = self.frame
# --> 469 self.truncate()
#     470 self.adj = printing.get_adjustment()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:655, in DataFrameFormatter.truncate(self)
#     651 """
#     652 Check whether the frame should be truncated. If so, slice the frame up.
#     653 """
#     654 if self.is_truncated_horizontally:
# --> 655     self._truncate_horizontally()
#     657 if self.is_truncated_vertically:
#     658     self._truncate_vertically()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:671, in DataFrameFormatter._truncate_horizontally(self)
#     669 col_num = self.max_cols_fitted // 2
#     670 if col_num >= 1:
# --> 671     left = self.tr_frame.iloc[:, :col_num]
#     672     right = self.tr_frame.iloc[:, -col_num:]
#     673     self.tr_frame = concat((left, right), axis=1)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# KeyboardInterrupt:

# %%
from exonamd.plot import plot_sample_namd

df_rel = df_namd.copy()
df_rel = df_rel[df_rel["hostname"] != "SSE"]

plot_sample_namd(df=df_rel, title="Core systems", kind="rel", out_path="./plots/core_planets_pop_namd_rel.pdf")
plot_sample_namd(df=None, title="Core systems", kind="abs", out_path="./plots/core_planets_pop_namd_abs.pdf")
# Out:
# 2025-07-09 20:56:32.379 | INFO     | exonamd.plot:plot_sample_namd:250 - Plotting the NAMD vs. multiplicity
# 2025-07-09 20:56:33.465 | INFO     | exonamd.plot:plot_sample_namd:262 - Plot done
# 2025-07-09 20:56:33.467 | INFO     | exonamd.plot:plot_sample_namd:245 - Reloading the database
# 2025-07-09 20:56:33.473 | INFO     | exonamd.plot:plot_sample_namd:247 - Database reloaded
# 2025-07-09 20:56:33.474 | INFO     | exonamd.plot:plot_sample_namd:250 - Plotting the NAMD vs. multiplicity
# 2025-07-09 20:56:34.609 | INFO     | exonamd.plot:plot_sample_namd:262 - Plot done

# %%
import numpy as np


df_namd_plot = df_namd.groupby("hostname")[
    [
        "namd_rel",
        "namd_abs",
        "namd_rel_q16",
        "namd_rel_q50",
        "namd_rel_q84",
        "namd_abs_q16",
        "namd_abs_q50",
        "namd_abs_q84",
    ]
].apply(lambda g: g.select_dtypes(exclude=["object"]).mean())


import matplotlib.pyplot as plt

fig = plt.figure()

plt.yscale("log")
plt.xscale("log")
plt.xlabel("namd_rel")
plt.ylabel("namd_abs")

plt.errorbar(
    x=df_namd_plot["namd_rel_q50"],
    y=df_namd_plot["namd_abs_q50"],
    xerr=(
        df_namd_plot["namd_rel_q84"] - df_namd_plot["namd_rel_q50"],
        df_namd_plot["namd_rel_q50"] - df_namd_plot["namd_rel_q16"],
    ),
    yerr=(
        df_namd_plot["namd_abs_q84"] - df_namd_plot["namd_abs_q50"],
        df_namd_plot["namd_abs_q50"] - df_namd_plot["namd_abs_q16"],
    ),
    fmt="o",
    markersize=3,
    capsize=5,
    alpha=0.5,
)

# SS = df_namd_plot[df_namd_plot.index == "SS"]

# plt.errorbar(
#     x=SS["namd_rel_q50"],
#     y=SS["namd_abs_q50"],
#     xerr=(
#         SS["namd_rel_q84"] - SS["namd_rel_q50"],
#         SS["namd_rel_q50"] - SS["namd_rel_q16"],
#     ),
#     yerr=(
#         SS["namd_abs_q84"] - SS["namd_abs_q50"],
#         SS["namd_abs_q50"] - SS["namd_abs_q16"],
#     ),
#     fmt="o",
#     markersize=3,
#     capsize=5,
#     alpha=0.5,
#     color="r",
# )

missing_mc = df_namd_plot[
    np.logical_or(df_namd_plot["namd_abs_q50"].isna(), df_namd_plot["namd_rel_q50"].isna())
]

plt.plot(
    missing_mc["namd_rel"],
    missing_mc["namd_abs"],
    "o",
    color="k",
    alpha=0.5,
    markersize=3,
)

ymin = 1e-6
ymax = 1
xmin = 1e-6
xmax = 1

plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
plt.vlines(1.3e-3, *plt.ylim(), colors=["k"], linestyles=["--"])
plt.hlines(1.3e-3, *plt.xlim(), colors=["k"], linestyles=["--"])

fig.text(0.3, 0.85, "Perturbed, non-excited", ha="center", va="center")
fig.text(0.7, 0.85, "Perturbed, excited", ha="center", va="center")

fig.text(0.3, 0.15, "Non-perturbed, non-excited", ha="center", va="center")
fig.text(0.7, 0.15, "Non-perturbed, excited", ha="center", va="center")

plt.show()

# %%
import numpy as np


df_namd_plot = df_namd.groupby("hostname")[
    [
        "namd_rel",
        "namd_abs",
        "namd_rel_q16",
        "namd_rel_q50",
        "namd_rel_q84",
        "namd_abs_q16",
        "namd_abs_q50",
        "namd_abs_q84",
    ]
].apply(lambda g: g.select_dtypes(exclude=["object"]).mean())


import matplotlib.pyplot as plt

fig = plt.figure()

plt.yscale("log")
plt.xscale("log")
plt.xlabel("namd_rel")
plt.ylabel("namd_abs")

plt.scatter(
    x=df_namd_plot["namd_rel"],
    y=df_namd_plot["namd_abs"],
)

ymin = 1e-6
ymax = 1
xmin = 1e-6
xmax = 1

plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
plt.vlines(1.3e-3, *plt.ylim(), colors=["k"], linestyles=["--"])
plt.hlines(1.3e-3, *plt.xlim(), colors=["k"], linestyles=["--"])

fig.text(0.3, 0.85, "Perturbed, non-excited", ha="center", va="center")
fig.text(0.7, 0.85, "Perturbed, excited", ha="center", va="center")

fig.text(0.3, 0.15, "Non-perturbed, non-excited", ha="center", va="center")
fig.text(0.7, 0.15, "Non-perturbed, excited", ha="center", va="center")

plt.show()

# %%
df_namd.sy_pnum.unique()
# Out:
# array([2, 5, 3, 4, 7, 6, 8])

# %%
df_namd[df_namd["hostname"] == "TOI-836"][["pl_trueobliq", "pl_relincl"]]
# Out:
#       pl_trueobliq  pl_relincl
# 3661          0.00        0.00
# 3663          1.13        1.13

# %%
df_namd[df_namd["hostname"] == "TOI-836"].columns
# Out:
# Index(['hostname', 'pl_name', 'rowupdate', 'sy_pnum', 'pl_orbsmax',
#        'pl_orbsmaxerr1', 'pl_orbsmaxerr2', 'pl_bmasse', 'pl_bmasseerr1',
#        'pl_bmasseerr2', 'pl_orbeccen', 'pl_orbeccenerr1', 'pl_orbeccenerr2',
#        'pl_trueobliq', 'pl_trueobliqerr1', 'pl_trueobliqerr2', 'st_rad',
#        'st_mass', 'pl_orbper', 'pl_ratdor', 'pl_ratror', 'flag', 'pl_relincl',
#        'pl_relinclerr1', 'pl_relinclerr2', 'namd_rel', 'namd_abs',
#        'namd_rel_mc', 'namd_rel_q16', 'namd_rel_q50', 'namd_rel_q84',
#        'namd_abs_mc', 'namd_abs_q16', 'namd_abs_q50', 'namd_abs_q84'],
#       dtype='object')
